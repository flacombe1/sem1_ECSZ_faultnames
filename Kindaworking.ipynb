# %%
# Load modules
import pandas as pd
import re
import ast
import glob
from pathlib import Path

path = "C:/Users/19049/coding_files/data/CFM5.3_traces.ts"
subset = "C:/Users/19049/coding_files/data/subset.ts"
folder = "C:/Users/19049/coding_files/faults/"

to_open = path

#currently the path is saevd as a .ts file, it'd be nice to have a conversion automatically from utm

# %%
#I did not write this https://stackoverflow.com/questions/185936/how-to-delete-the-contents-of-a-folder
#Just a tool to clear the faults folder- but could be useful later when reading in new data
def Delete_faults_content():
    [f.unlink() for f in Path("C:/Users/19049/coding_files/faults").glob("*") if f.is_file()]
Delete_faults_content()

# %%
# @title
#what i've got:
#strip the crap from the fault name line (the tag and excess quotes, can expand to more stuff)
#open a fault folder to stick the coords in

#What i want:
#how tf do I put the coords into the new files now- I think I can use the current name and use the make_new_fault as a ticker, so the "put number in folder" function is dumb and every time it sees
#a coord it will just add it to the fault that is currently "name" and that should change since the for loop goes down the list in order
#it'd be nice to get a counter as a discrepancy check

#strips "> " and extra "" from line and sets it to global name
def redefine_name():
    global name
    t1_name = line
    t2_name = re.sub("[> ]", "", t1_name)
    name = ast.literal_eval(t2_name)

#makes an empty pandas dataframe using the empty list l
def make_new_fault():
    global l1
    l1 = pd.DataFrame(l,columns = ['Easting(m)','Northing(m)','Elevation(m)'])

#the line being read is delimited and turned from a line of strings into a line of floats
#then it is apended to the l1 dataframe
def number_line():
    global float_list
    string_line = line.split()
    float_list = list(map(float, string_line))
    l1.loc[len(l1)] = float_list

#takes the finished l1 dataframe and names it the current fault trace, making it a csv    
def save_line():
    l1.to_csv(folder+name+".csv")

# %%
#l being here resets the dataframe every time it's run
l = []
with open(to_open, encoding='utf-8') as f:
    for line in f:
        if line.startswith("> "):
            is_number = False
            redefine_name()
            make_new_fault()
            print(name)
        elif line.startswith("#"):
            print("doin nothing")
        else:
            is_number = True
            while is_number == True:
                if not line.startswith("> "):
                    number_line()
                break
            save_line()
# Out:
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# doin nothing
# BNRA-BMFZ-MULT-Black_Mountain_fault-CFM3
# BNRA-NDVZ-MULT-Northern_Death_Valley_fault-CFM2
# BNRA-SDVZ-MULT-Southern_Death_Valley_fault_vertical-CFM3
# CRFA-BPPM-EAST-Big_Pine_fault-CFM4
# CRFA-BPPM-LKWV-Lockwood_Valley_fault-CFM2
# CRFA-BPPM-PMTS-Pine_Mountain_fault-CFM2
# CRFA-BPPM-WEST-Big_Pine_fault-CFM2
# CRFA-CSBL-CSML-Casmalia_fault-CFM4
# CRFA-CSBL-LALM-Los_Alamos_fault_steep-CFM5
# CRFA-CSBL-PEZN-Pezzoni_Casmalia_fault_truncated-CFM5
# CRFA-LNHZ-MULT-Lions_Head_fault-CFM4
# CRFA-LOSO-LSOS-Los_Osos_fault-CFM4
# CRFA-LPNZ-MULT-La_Panza_fault-CFM4
# CRFA-NAFZ-MULT-Nacimiento_fault_south-CFM2
# CRFA-OCNZ-HSNV-West_Huasna_fault-CFM5
# CRFA-OCNZ-MULT-Oceanic_fault-CFM5
# PNRA-EMCP-2010-El_Mayor_Cucapah_rupture-CFM5
# PNRA-HSSF-AGCT-Agua_Caliente_fault_zone-CFM4
# PNRA-HSSF-AGCT-Agua_Caliente_fault_zone-CFM4
# PNRA-HSSF-AGCT-Agua_Caliente_fault_zone-CFM4
# PNRA-HSSF-AGCT-Agua_Caliente_fault_zone-CFM4
# PNRA-HSSF-AGCT-Agua_Caliente_fault_zone-CFM4
# PNRA-HSSF-HOTS-Hot_Springs_fault-CFM4
# PNRA-HSSF-MRHS-Murrieta_Hotsprings_fault-CFM4
# PNRA-NBJD-CDVD-Canada_David_detachment-CFM3
# PNRA-NBJD-SRCP-Cerro_Centinela_fault-CFM2
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-NIRC-LABS-Newport_Inglewood_fault_dip_w_splays_split-CFM5
# PNRA-SJFZ-ANZA-Buck_Ridge_fault-CFM4
# PNRA-SJFZ-ANZA-Clark_fault_north-CFM4
# PNRA-SJFZ-ANZA-Clark_fault_south_east-CFM4
# PNRA-SJFZ-ANZA-Clark_fault_south_main-CFM4
# PNRA-SJFZ-ANZA-Hot_Springs_Buck_Ridge_link-CFM4
# PNRA-SJFZ-BRMT-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-BRMT-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-BRMT-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-CYTC-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-CYTC-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-CYTC-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-CYTC-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-CYTC-Coyote_Creek_fault-CFM4
# PNRA-SJFZ-CYTC-Coyote_Creek_fault_center_east_splay-CFM4
# PNRA-SJFZ-IMPV-Weinert_Superstition_Hills_link-CFM5
# PNRA-SJFZ-SBRN-Glen_Helen_fault-CFM4
# PNRA-SJFZ-SBRN-Loma_Linda_fault-CFM4
# PNRA-SJFZ-SBRN-Lytle_Creek_fault-CFM5
# PNRA-SJFZ-SBRN-Rialto_Colton_fault-CFM4
# PNRA-SJFZ-SBRN-San_Jacinto_Claremont_fault-CFM4
# PNRA-SJFZ-SJCV-Casa_Loma_fault-CFM4
# PNRA-SJFZ-SJCV-Claremont_fault-CFM4
# PNRA-SJFZ-SJCV-Hot_Springs_fault-CFM4
# PNRA-SJFZ-SJCV-Hot_Springs_fault_west-CFM4
# PNRA-SJFZ-SJCV-San_Jacinto_Claremont_fault_east-CFM4
# PNRA-SJFZ-SSHS-Superstition_Hills_fault-CFM4
# WTRA-PHTS-PRTH-Peralta_Hills_fault-CFM1
# WTRA-SCFZ-SCLV-Del_Valle_fault-CFM2
# WTRA-SCFZ-SCLV-Holser_fault-CFM2
# WTRA-SCFZ-TOPA-San_Cayetano_fault-CFM5
# WTRA-SFFS-ANCP-Malibu_Coast_fault_west_steep_alt2-CFM5
# WTRA-SFFS-LABS-Hollywood_fault-CFM5
# WTRA-SFFS-SGVS-Raymond_fault_extended-CFM5
# WTRA-SFFS-SMMT-Malibu_Coast_fault_east_steep_alt2-CFM5
# WTRA-SFFS-SMMT-Santa_Monica_fault_steep-CFM5
# WTRA-SFFS-SMMT-Santa_Monica_fault_steep-CFM5
# WTRA-SFFS-SMMT-Santa_Monica_fault_steep-CFM5
# WTRA-SFFS-SNCZ-Santa_Cruz_Island_fault-CFM5
# WTRA-SFNS-MSNH-Mission_Hills_fault-CFM4
# WTRA-SFNS-SFNV-Northridge_Hills_fault_truncated-CFM3
# WTRA-SFNS-SFNV-San_Fernando_fault-CFM4
# WTRA-SFNS-VRDM-Eagle_Rock_fault_steep-CFM5
# WTRA-SFNS-VRDM-Verdugo_fault_steep-CFM5
# WTRA-SGFZ-BTJG-San_Gabriel_fault_splay-CFM4
# WTRA-SGFZ-MULT-Southern_San_Gabriel_fault-CFM4
# WTRA-SGFZ-PLMS-Northern_San_Gabriel_fault-CFM4
# WTRA-SGFZ-USGR-Weber_fault-CFM5
# WTRA-SGFZ-USGR-Weber_fault_NE_extension-CFM5
# WTRA-SGMF-ICHC-Icehouse_Canyon_fault_truncated-CFM5
# WTRA-SGMF-SANC-San_Antonio_Canyon_fault-CFM5
# WTRA-SGMF-SANC-San_Antonio_Canyon_fault_splay_truncated-CFM5
# WTRA-SGMF-STDC-South_Fork_Stoddard_Canyon_fault_truncated-CFM5
# WTRA-SGMF-STDC-Stoddard_Canyon_fault_truncated-CFM5
# WTRA-SMFZ-CCMG-Cucamonga_fault_low_dip-CFM5
# WTRA-SMFZ-CSPC-Clamshell_Sawpit_Canyon_fault-CFM4
# WTRA-SMFZ-MULT-Sierra_Madre_fault_west-CFM4
# WTRA-SMFZ-SMCC-Sierra_Madre_fault_low_dip-CFM4
# WTRA-SMFZ-SMDD-Sierra_Madre_fault_low_dip-CFM4
# WTRA-SMFZ-SMDE-Sierra_Madre_Cucamonga_connector-CFM5
# WTRA-SMFZ-SMDE-Sierra_Madre_fault_low_dip-CFM4
# WTRA-SPJD-SPMT-Lion_Canyon_fault-CFM5
# WTRA-SPJS-MULT-Padre_Juan_fault-CFM5
# WTRA-SPJS-SMGA-Javon_Canyon_fault-CFM5
# WTRA-SSFZ-MULT-Santa_Susana_fault-CFM5
# WTRA-SSRZ-MULT-Simi_Santa_Rosa_fault_listric-CFM5
# WTRA-SSRZ-OXNP-Bailey_fault_steep-CFM5
# WTRA-SYFZ-MULT-Santa_Ynez_fault_75dip-CFM5
# WTRA-SYRZ-MULT-Santa_Ynez_River_fault-CFM5
# WTRA-USAV-USAV-Indian_Hill_fault-CFM5
# WTRA-USAV-USAV-San_Jose_fault-CFM5
# WTRA-USAV-USAV-Upland_fault_dipslip-CFM1
# WTRA-USAV-USAV-Walnut_Creek_fault-CFM5
